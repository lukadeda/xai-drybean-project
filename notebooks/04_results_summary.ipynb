# %% [markdown]
# # 04 Ergebniszusammenfassung
#
# Dieses Notebook sammelt finale Tabellen, Grafiken und kurze Textbausteine fuer Bericht und Praesentation.

# %% [markdown]
# ## Forschungsfrage
#
# Inwiefern lassen sich Dry-Bean-Sorten anhand weniger morphologischer Bildmerkmale zuverlaessig klassifizieren, und welche Merkmale erklaeren die Entscheidungen verschiedener Multiclass-Klassifikatoren am staerksten?

# %% [markdown]
# ## Modellvergleich
#
# Hier spaeter die Ergebnis-Tabelle aus `02_model_training.ipynb` eintragen oder erneut laden.

# %% [markdown]
# ## Feature-Auswahl
#
# Erste Feature-Auswahl: `Area`, `AspectRation`, `Eccentricity`, `Compactness`, `Roundness`, `ShapeFactor1`, `ShapeFactor2`, `ShapeFactor3`.
#
# Begruendung: Die Auswahl kombiniert ein Groessenmerkmal mit mehreren Formmerkmalen und reduziert redundante Groesseninformationen.

# %% [markdown]
# ## XAI-Zusammenfassung
#
# Hier spaeter die wichtigsten globalen und lokalen Erklaerungen zusammenfassen. Relevant ist besonders, ob Groesse, Rundheit und Laenglichkeit fachlich plausible Modellentscheidungen erklaeren.

# %% [markdown]
# ## Kritische Diskussion
#
# Leitfragen:
#
# - Stimmen die wichtigsten Features mit dem Domaenenwissen ueberein?
# - Sind einzelne Features schwer interpretierbar?
# - Gibt es Klassen, die systematisch verwechselt werden?
# - Wie beeinflussen korrelierte Features die Erklaerungen?
